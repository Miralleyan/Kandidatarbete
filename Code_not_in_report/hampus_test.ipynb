# %%
import matplotlib.pyplot as plt
import torch
import pytorch_measure as pm
import numpy as np
N = 17 # number of atoms
M = 2000 # Number of datapoints
amin = -5
amax = 3
verbose = True
dev = 'cpu'


torch.manual_seed(1)

def regression_model(x, list):
    return list[0] + x

x = torch.linspace(0, 10, M).view(-1, 1)
data = regression_model(torch.randn(M).to(dev) - 2, x.view(1, -1)).view(-1, 1)
w = torch.rand(N,dtype=torch.float).to(dev)
w = torch.nn.parameter.Parameter(w/w.sum())
l = torch.linspace(amin, amax, N, requires_grad=False).to(dev)

index = []
for i in range(M):
    ab = (regression_model(x[i], [l]) - data[i]).abs()
    index.append(torch.argmin(ab))

def NLLLoss(m:list[pm.Measure]):
    return -(m[0].weights[index]).log().sum()

sd = (l[index] - data)**2
def WardLoss(w):
    return sum(sd * w[index])

def K(d):
        return 1/np.sqrt(2*np.pi)*np.exp(-d**2/2)

# %%
measure = pm.Measure(locations=l, weights=w, device=dev)

opt_KDE = pm.Optimizer([measure], loss='KDEnll', lr=1e-1)
new_mesKDE = opt_KDE.minimize(verbose=True, model=regression_model, data=[x, data], print_freq=10, max_epochs=1000, tol_const=1e-3, adaptive=True)
'''
opt_NLL = pm.Optimizer([measure], loss='nll', lr=1e-1)
new_mes = opt_NLL.minimize(verbose=True, model=regression_model, data=[x, data], print_freq=10, max_epochs=1000, tol_const=1e-3, adaptive=True)
'''


#plt.bar(l + 0.1, new_mes[0].weights.tolist(), width = 0.2, label='NLL')
new_mesKDE[0].visualize()
plt.show()
# Out:
# Epoch: 0          Loss: 3665.197265625 LR: [0.1]
# Epoch: 4          Lr was reduced to: [0.010000000000000002]
# Epoch: 10         Loss: 2939.451416016 LR: [0.010000000000000002]
# Epoch: 15         Lr was reduced to: [0.0010000000000000002]
# Epoch: 20         Loss: 2919.233154297 LR: [0.0010000000000000002]
# Epoch: 30         Loss: 2913.328125000 LR: [0.0010000000000000002]
# Epoch: 40         Loss: 2908.462646484 LR: [0.0010000000000000002]
# Epoch: 50         Loss: 2904.291503906 LR: [0.0010000000000000002]
# Epoch: 60         Loss: 2900.957275391 LR: [0.0010000000000000002]
# Epoch: 70         Loss: 2898.179443359 LR: [0.0010000000000000002]
# Epoch: 80         Loss: 2896.547851562 LR: [0.0010000000000000002]
# Epoch: 90         Loss: 2895.436035156 LR: [0.0010000000000000002]
# Epoch: 95         Lr was reduced to: [0.00010000000000000003]
# Epoch: 100        Loss: 2895.062988281 LR: [0.00010000000000000003]
# Epoch: 110        Loss: 2894.975830078 LR: [0.00010000000000000003]
# Epoch: 120        Loss: 2894.906738281 LR: [0.00010000000000000003]
# Epoch: 130        Loss: 2894.846435547 LR: [0.00010000000000000003]
# Epoch: 140        Loss: 2894.790283203 LR: [0.00010000000000000003]
# Epoch: 150        Loss: 2894.735839844 LR: [0.00010000000000000003]
# Epoch: 160        Loss: 2894.682617188 LR: [0.00010000000000000003]
# Epoch: 170        Loss: 2894.630859375 LR: [0.00010000000000000003]
# Epoch: 180        Loss: 2894.579833984 LR: [0.00010000000000000003]
# Epoch: 190        Loss: 2894.530273438 LR: [0.00010000000000000003]
# Epoch: 200        Loss: 2894.480957031 LR: [0.00010000000000000003]
# Epoch: 210        Loss: 2894.433593750 LR: [0.00010000000000000003]
# Epoch: 220        Loss: 2894.387939453 LR: [0.00010000000000000003]
# Epoch: 230        Loss: 2894.342529297 LR: [0.00010000000000000003]
# Epoch: 240        Loss: 2894.298339844 LR: [0.00010000000000000003]
# Epoch: 250        Loss: 2894.255126953 LR: [0.00010000000000000003]
# Epoch: 260        Loss: 2894.213867188 LR: [0.00010000000000000003]
# Epoch: 270        Loss: 2894.172851562 LR: [0.00010000000000000003]
# Epoch: 280        Loss: 2894.134277344 LR: [0.00010000000000000003]
# Epoch: 290        Loss: 2894.096191406 LR: [0.00010000000000000003]
# Epoch: 300        Loss: 2894.059326172 LR: [0.00010000000000000003]
# Epoch: 310        Loss: 2894.023681641 LR: [0.00010000000000000003]
# Epoch: 320        Loss: 2893.989990234 LR: [0.00010000000000000003]
# Epoch: 330        Loss: 2893.956542969 LR: [0.00010000000000000003]
# Epoch: 340        Loss: 2893.925292969 LR: [0.00010000000000000003]
# Epoch: 350        Loss: 2893.895263672 LR: [0.00010000000000000003]
# Epoch: 360        Loss: 2893.866699219 LR: [0.00010000000000000003]
# Epoch: 370        Loss: 2893.839111328 LR: [0.00010000000000000003]
# Epoch: 380        Loss: 2893.812255859 LR: [0.00010000000000000003]
# Epoch: 390        Loss: 2893.786132812 LR: [0.00010000000000000003]
# Epoch: 400        Loss: 2893.760986328 LR: [0.00010000000000000003]
# Epoch: 410        Loss: 2893.735839844 LR: [0.00010000000000000003]
# Epoch: 420        Loss: 2893.711914062 LR: [0.00010000000000000003]
# Epoch: 430        Loss: 2893.688476562 LR: [0.00010000000000000003]
# Epoch: 440        Loss: 2893.665771484 LR: [0.00010000000000000003]
# Epoch: 450        Loss: 2893.644287109 LR: [0.00010000000000000003]
# Epoch: 460        Loss: 2893.630859375 LR: [0.00010000000000000003]
# Epoch: 470        Loss: 2893.616943359 LR: [0.00010000000000000003]
# Epoch: 480        Loss: 2893.596435547 LR: [0.00010000000000000003]
# Epoch: 490        Loss: 2893.576416016 LR: [0.00010000000000000003]
# Epoch: 500        Loss: 2893.556640625 LR: [0.00010000000000000003]
# Epoch: 510        Loss: 2893.538085938 LR: [0.00010000000000000003]
# Epoch: 520        Loss: 2893.520751953 LR: [0.00010000000000000003]
# Epoch: 530        Loss: 2893.504150391 LR: [0.00010000000000000003]
# Epoch: 540        Loss: 2893.486816406 LR: [0.00010000000000000003]
# Epoch: 550        Loss: 2893.469970703 LR: [0.00010000000000000003]
# Epoch: 560        Loss: 2893.454833984 LR: [0.00010000000000000003]
# Epoch: 570        Loss: 2893.442382812 LR: [0.00010000000000000003]
# Epoch: 580        Loss did not change (2893.4345703125)
# Epoch: 590        Loss: 2893.426269531 LR: [0.00010000000000000003]
# Epoch: 600        Loss: 2893.413330078 LR: [0.00010000000000000003]
# Epoch: 610        Loss: 2893.399658203 LR: [0.00010000000000000003]
# Epoch: 620        Loss: 2893.385742188 LR: [0.00010000000000000003]
# Epoch: 630        Loss: 2893.372070312 LR: [0.00010000000000000003]
# Epoch: 640        Loss: 2893.362792969 LR: [0.00010000000000000003]
# Epoch: 645        Loss did not change (2893.35986328125)
# Epoch: 650        Loss: 2893.356201172 LR: [0.00010000000000000003]
# Epoch: 660        Loss: 2893.349365234 LR: [0.00010000000000000003]
# Epoch: 667        Loss did not change (2893.34521484375)
# Epoch: 670        Loss: 2893.342773438 LR: [0.00010000000000000003]
# Epoch: 679        Loss did not change (2893.337646484375)
# Epoch: 680        Loss: 2893.336425781 LR: [0.00010000000000000003]
# Epoch: 683        Loss did not change (2893.3349609375)
# Epoch: 689        Lr was reduced to: [1.0000000000000004e-05]
# Epoch: 690        Lr was reduced to: [1.0000000000000004e-06]
# Epoch: 691        Lr was reduced to: [1.0000000000000005e-07]
# The step size is too small: [1.0000000000000005e-07]

# %%
samp = new_mesKDE[0].sample(10000)
plt.hist(samp, rwidth=0.3, range=[-5, 3], bins=50)
plt.show()

# %%
checker = pm.Check(opt_KDE, regression_model, x, data)
checker.check()
# Out:
# 204 is outside the confidence interval (81.0, 120.0):
# Number of misses is significantly at 95.0% confidence level different from expected for the fitted model!
